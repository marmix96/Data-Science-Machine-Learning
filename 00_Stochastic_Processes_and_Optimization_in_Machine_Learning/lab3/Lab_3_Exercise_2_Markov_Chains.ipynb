# %% [markdown]
# <h1><b>Άσκηση 2</b></h1>
# <p align="justify">Σας δίνεται η παρακάτω στοχαστική μήτρα πιθανοτήτων P μιας μαρκοβιανής αλυσίδας. Από τη μήτρα αυτή έχουν παραλειφθεί ορισμένα στοιχεία:</p>
# <img src="https://raw.githubusercontent.com/nkostopoulos/StochasticsLabPublic/master/lab3/ex2.PNG"><img>
# <ul>

# %% [markdown]
# <li>Να συμπληρώσετε τα κενά της μήτρας πιθανοτήτων P της μαρκοβιανής αλυσίδας.</li>

# %% [markdown]
# (α) Ο πίνακας μεταβάσεων μίας μαρκοβιανής αλυσίδας, έστω P, πρέπει να έχει μία βασική ιδιότητα. Οι γραμμές του να αθροίζουν στο 1. Με βάση λοιπόν αυτή την παρατήρηση, ο πίνακας P για την συγκεκριμένη άσκηση παρουσιάζεται ακολούθως:
# \begin{equation}
#             P =
#             \begin{bmatrix}
#                 0.6 & 0.2 & 0 & 0 & 0 & 0.2 \\
#                 0.2 & 0.6 & 0.2 & 0 & 0 & 0 \\
#                 0 & 0.2 & 0.6 & 0.2 & 0 & 0 \\
#                 0 & 0 & 0.2 & 0.6 & 0.2 & 0 \\
#                 0 & 0 & 0 & 0.2 & 0.6 & 0.2 \\
#                 0.2 & 0 & 0 & 0 & 0.2 & 0.6
#             \end{bmatrix}
# \end{equation}

# %% [markdown]
# <li>Χρησιμοποιώντας τον <a href="http://setosa.io/markov/index.html#%7B%22tm%22%3A%5B%5B0.6%2C0.2%2C0%2C0%2C0%2C0.2%5D%2C%5B0.2%2C0.6%2C0.2%2C0%2C0%2C0%5D%2C%5B0%2C0.2%2C0.6%2C0.2%2C0%2C0%5D%2C%5B0%2C0%2C0.2%2C0.6%2C0.2%2C0%5D%2C%5B0%2C0%2C0%2C0.2%2C0.6%2C0.2%5D%2C%5B0.2%2C0%2C0%2C0%2C0.2%2C0.6%5D%5D%7D">προσομοιωτή</a> να σχεδιάσετε την παραπάνω μαρκοβιανή αλυσίδα και να ταξινομήσετε τις καταστάσεις της σε κλάσεις επικοινωνίας. Πώς αποκαλείται μια τέτοια αλυσίδα με κριτήριο τις κλάσεις επικοινωνίας; Τι συμπέρασμα βγάζετε σχετικά με την ύπαρξη αναλλοίωτης κατανομής για την αλυσίδα;</li>

# %% [markdown]
# Όλες οι καταστάσεις επικοινωνίας της συγκεκριμένης μαρκοβιανής αλυσίδας, ανήκουν στην ίδια κλάση επικοινωνίας, αφού $\forall \text{ } i,j \in \mathbb{X} \text{ } \exists \text{ } i \rightarrow j$ (δηλαδή υπάρχει μονοπάτι από το i στο j (επικοινωνούν)). Τέτοιου είδους μαρκοβιανές αλυσίδες καλούνται μη-υποβιβάσιμες αλυσίδες (irreducible). Είναι γνωστό από την θεωρία ότι υπάρχει μοναδική αναλλοίωτη κατανομή για την αλυσίδα.
#
#
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# <li>Χρησιμοποιώντας τον κώδικα που παρατίθεται στο τέλος της άσκησης θα εκτιμήσετε την αναλλοίωτη κατανομή της μαρκοβιανής αλυσίδας με τη μέθοδο της προσομοίωσης. Το πρόγραμμα: (α) ορίζει τη μήτρα πιθανοτήτων και την αρχική κατανομή της αλυσίδας, (β) ορίζει το μοντέλο της και (γ) εκτιμά την αναλλοίωτη κατανομή της αλυσίδας για κάθε κατάσταση, διαιρώντας τον αριθμό των επισκέψεων στην κατάσταση αυτή με το συνολικό αριθμό των βημάτων της αλυσίδας (παράμετρος <i>total_runs</i>). Το πρόγραμμα δίνει ως έξοδο ένα ραβδόγραμμα που απεικονίζει την αναλλοίωτη κατανομή της αλυσίδας. Να καταγράψετε το αποτέλεσμα της εκτέλεσης του προγράμματος για συνολικό αριθμό βημάτων της αλυσίδας (α) 500, (β) 1,000, (γ) 10,000, (δ) 100,000, (ε) 1,000,000, (στ) 10,000,000 και (ζ) 100,000,000. Πόσο μεταβάλεται η εκτίμηση ανάμεσα σε κάθε έξοδο; Τι παρατηρείτε σχετικά με το συνολικό χρόνο εκτέλεσης της προσομοίωσης ανάλογα με το συνολικό αριθμό βημάτων της αλυσίδας; Κατά τη γνώμη σας, ποια τιμή του συνολικού αριθμού των βημάτων της αλυσίδας επιτυγχάνει μια ικανοποιητική ισορροπία ανάμεσα στην ακρίβεια του αποτελέσματος και το συνολικό χρόνο εκτέλεσης της προσομοίωσης; <b>Για να τρέξετε το πρόγραμμα θα πρέπει να έχετε φορτώσει το αρχείο <i><a href="https://github.com/nkostopoulos/StochasticsLabPublic/blob/master/lab3/simple_markov_chain_lib.py">simple_markov_chain_lib.py</a></i>.</b></li>

# %%
from __future__ import division
from simple_markov_chain_lib import markov_chain
import numpy as np
import matplotlib.pyplot as plt

from time import perf_counter # added library to time the simulations

def defineMarkovTable(): 
    markov_table = {
        0: {0: 0.6, 1: 0.2, 5: 0.2},
        1: {0: 0.2, 1: 0.6, 2: 0.2},
        2: {1: 0.2, 2: 0.6, 3: 0.2},
        3: {2: 0.2, 3: 0.6, 4: 0.2},
        4: {3: 0.2, 4: 0.6, 5: 0.2},
        5: {0: 0.2, 4: 0.2, 5: 0.6}
        }

    return markov_table

def defineInitDistribution():
    init_dist = {0: 1.}
    
    return init_dist

def calculateFrequencyTable(markov_table, init_dist, total_runs): # parse total_runs as argument, so we can loop
    
    visits = list()
    visits = [0] * len(markov_table)

    for index in range(total_runs):
        mc.move()
        visits[mc.running_state] += 1
    
    frequency = [v/total_runs for v in visits]
    
    return frequency

def printFrequencies(frequency, markov_table):
    for state in range(0, len(markov_table)) :
        print(str(state) + ": ", str(frequency[state]))
    
    return None

def plotFrequencies(frequency):
    objects = ('1', '2', '3', '4', '5', '6')
    y_pos = np.arange(len(objects))

    plt.bar(y_pos, frequency, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('States')
    plt.title('Frequencies')
    plt.show()

    return None

if __name__ == "__main__":
    markov_table = defineMarkovTable()
    init_dist = defineInitDistribution()
    for total_runs in [500, 1000, 10000, 100000, 1000000, 10000000, 100000000]:
        t1_start = perf_counter()
        mc = markov_chain(markov_table, init_dist)
        mc.start()

        frequency = calculateFrequencyTable(markov_table, init_dist, total_runs)
        t1_end = perf_counter()
        
        print("Total time for {} runs: {:.4f} seconds".format(total_runs, t1_end - t1_start))
        printFrequencies(frequency, markov_table)
        plotFrequencies(frequency)
# Out:
# Total time for 500 runs: 0.2561 seconds
# 0:  0.12
# 1:  0.19
# 2:  0.186
# 3:  0.138
# 4:  0.202
# 5:  0.164
# Total time for 1000 runs: 0.0021 seconds
# 0:  0.201
# 1:  0.154
# 2:  0.137
# 3:  0.18
# 4:  0.153
# 5:  0.175
# Total time for 10000 runs: 0.0116 seconds
# 0:  0.1622
# 1:  0.1697
# 2:  0.1792
# 3:  0.1657
# 4:  0.1617
# 5:  0.1615
# Total time for 100000 runs: 0.1142 seconds
# 0:  0.16636
# 1:  0.16636
# 2:  0.16319
# 3:  0.16431
# 4:  0.17075
# 5:  0.16903
# Total time for 1000000 runs: 1.1447 seconds
# 0:  0.166306
# 1:  0.166976
# 2:  0.167824
# 3:  0.1673
# 4:  0.166384
# 5:  0.16521
# Total time for 10000000 runs: 11.1557 seconds
# 0:  0.1668902
# 1:  0.1669909
# 2:  0.1668689
# 3:  0.1663164
# 4:  0.1663604
# 5:  0.1665732
# Total time for 100000000 runs: 110.9273 seconds
# 0:  0.16666276
# 1:  0.1666418
# 2:  0.16660944
# 3:  0.16662977
# 4:  0.16671475
# 5:  0.16674148

# %% [markdown]
# Ακολούθως παρουσιάζεται η αναλοίωτη κατανομή που προκύπτει από διαδοχικές εκτελέσεις του δοσμένου κώδικα, για διαφορετικό αριθμό βημάτων στην αλυσίδα, έστω k:
# <li> k = 500: $\pi = \left\{0.12, 0.19, 0.186, 0.138, 0.202, 0.164\right\}$, <br>
# time: $0.2561$ seconds (αυξημένος χρόνος λόγω φόρτωσης βιβλιοθηκών) </li>
# <li> k = 1.000: $\pi = \left\{0.201, 0.154, 0.137, 0.18, 0.153, 0.175\right\}$, <br>
# time: $0.0021$ seconds </li>
# <li> k = 10.000: $\pi = \left\{0.1622, 0.1697, 0.1792, 0.1657, 0.1617, 0.1615\right\}$, <br>
# time: $0.0116$ seconds </li>
# <li> k = 100.000: $\pi = \left\{0.16636, 0.16636, 0.16319, 0.16431, 0.17075, 0.16903\right\}$, <br>
# time: $0.1142$ seconds </li>
# <li> k = 1.000.000: $\pi = \left\{0.166306, 0.166976, 0.167824, 0.1673, 0.166384, 0.16521\right\}$, <br>
# time: $1.1447$ seconds </li>
# <li> k = 10.000.000: $\pi = \left\{0.1668902, 0.1669909, 0.1668689, 0.1663164, 0.1663604, 0.1665732\right\}$, <br>
# time: $11.1557$ seconds </li>
# <li> k = 100.000.000: $\pi = \left\{0.16666276, 0.1666418, 0.16660944, 0.16662977, 0.16671475, 0.16674148\right\}$, <br>
# time: $110.9273$ seconds </li>
#
# Γίνεται εμφανές ότι καθώς αυξάνεται ο αριθμός των βημάτων προσομοίωσης της αλυσίδας ($k$), τόσο απαιτείται περισσότερος χρόνος για την ολοκλήρωση της εκτέλεσης του προγράμματος, κάτι που είναι διαισθητικά αναμενόμενο. Επιπλέον ανάλογα με την ακρίβεια που επιθυμούμε, θα επιλέγαμε $k = 100.000$ ή $k = 1.000.000$, ώστε να έχουμε μια ικανοποιητική ισορροπία ακρίβειας-χρόνου. Σε αυτές τις τιμές ουσιαστικά παρατηρούμε να επιτυγχάνεται αρχικά η σύγκλιση στις τελικές τιμές.
# Παρατήρηση: Ο χρόνος από τις 10.000 επαναλήψεις και πάνω είναι γραμμικός ως προς τον αριθμό των βημάτων. Δηλαδή, 10x βήματα μας δίνουν 10x χρόνο.

# %% [markdown]
# <li>Τι παρατηρείτε σχετικά με τις τιμές της αναλλοίωτης κατανομής της παραπάνω μαρκοβιανής αλυσίδας; Να υπολογίσετε το άθροισμα των στοιχείων κάθε στήλης της μήτρας πιθανοτήτων <b>P</b>. Πώς ονομάζεται μία τέτοια μήτρα πιθανοτήτων και τι ισχύει για την αναλλοίωτη κατανομή μιας τέτοιας αλυσίδας;</li>

# %% [markdown]
# Ο συγκεκριμένος πίνακας μεταβάσεων ανήκει στην κατηγορία των διπλά στοχαστικών πινάκων μετάβασης, διότι και το άθροισμα των στηλών είανι 1. Αυτό σε συνδυασμό με το ότι η αλυσίδα είναι μη-υποβιβάσιμη (διαθέτει μοναδική αναλοίωτη κατανομή) δίνει θεωρητικά τις εξής τιμές για την αναλλοίωτη κατανομή:
# \begin{equation}
#     \begin{aligned}
#         \pi_{i} = \frac{1}{|\mathbb{X}|}, \forall i \text{ } \in \mathbb{X}, \text{ } όπου \text{ } |\mathbb{X}| = 6 \text{ } \text{στην περίπτωση μας}
#     \end{aligned}
# \end{equation}
# Αυτό επαλυθεύεται και από την εκτέλεση του αντίστοιχου προγραμμάτος, καθώς εν τέλει λαμβάνουμε σύγκλιση σε μια τιμή κοντά στο $0.166$ δηλαδή κοντά στο $\frac{1}{n}$, όπου $ n = 6 $ στην περίπτωση μας.
